# %%
import pandas as pd

# %%
df = pd.read_csv("./bank-additional-full.csv")

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df = df.drop(['y','pdays','previous','euribor3m','emp.var.rate'],axis=1)

# %%
df.rename(columns={'contact':'comm_type','duration':'last_contact_duration','campaign':'campaign_contact_count'},inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'comm_type', 'month', 'day_of_week', 'last_contact_duration',
#        'campaign_contact_count', 'poutcome', 'cons.price.idx', 'cons.conf.idx',
#        'nr.employed'],
#       dtype='object')

# %%
d = pd.read_csv("customer_data.csv")

# %%
# Out:
#        Unnamed: 0  age          job  marital            education  default  \
# 0               0   56    housemaid  married             basic.4y       no
# 1               1   57     services  married          high.school  unknown
# 2               2   37     services  married          high.school       no
# 3               3   40       admin.  married             basic.6y       no
# 4               4   56     services  married          high.school       no
# ...           ...  ...          ...      ...                  ...      ...
# 41183       41183   73      retired  married  professional.course       no
# 41184       41184   46  blue-collar  married  professional.course       no
# 41185       41185   56      retired  married    university.degree       no
# 41186       41186   44   technician  married  professional.course       no
# 41187       41187   74      retired  married  professional.course       no
#
#       housing loan  comm_type month day_of_week  last_contact_duration  \
# 0          no   no  telephone   may         mon                    261
# 1          no   no  telephone   may         mon                    149
# 2         yes   no  telephone   may         mon                    226
# 3          no   no  telephone   may         mon                    151
# 4          no  yes  telephone   may         mon                    307
# ...       ...  ...        ...   ...         ...                    ...
# 41183     yes   no   cellular   nov         fri                    334
# 41184      no   no   cellular   nov         fri                    383
# 41185     yes   no   cellular   nov         fri                    189
# 41186      no   no   cellular   nov         fri                    442
# 41187     yes   no   cellular   nov         fri                    239
#
#        campaign_contact_count     poutcome  cons.price.idx  cons.conf.idx  \
# 0                           1  nonexistent          93.994          -36.4
# 1                           1  nonexistent          93.994          -36.4
# 2                           1  nonexistent          93.994          -36.4
# 3                           1  nonexistent          93.994          -36.4
# 4                           1  nonexistent          93.994          -36.4
# ...                       ...          ...             ...            ...
# 41183                       1  nonexistent          94.767          -50.8
# 41184                       1  nonexistent          94.767          -50.8
# 41185                       2  nonexistent          94.767          -50.8
# 41186                       1  nonexistent          94.767          -50.8
# 41187                       3      failure          94.767          -50.8
#
#        nr.employed
# 0           5191.0
# 1           5191.0
# 2           5191.0
# 3           5191.0
# 4           5191.0
# ...            ...
# 41183       4963.6
# 41184       4963.6
# 41185       4963.6
# 41186       4963.6
# 41187       4963.6
#
# [41188 rows x 17 columns]
