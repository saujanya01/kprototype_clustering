# %%
import pandas as pd

# %%
df = pd.read_csv('./with_cluster_full.csv')

# %%
ind = []
l = df.dtypes
for i in range(len(l)):
    if (str(l[i])=='object'):
        ind.append(i)
c_data = [df.columns[i] for i in ind]
c_data
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'comm_type',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
df[df['cluster']==0]
# Out:
#        age          job   marital            education default housing loan  \
# 0       56    housemaid   married             basic.4y      no      no   no
# 4       56     services   married          high.school      no      no  yes
# 8       24   technician    single  professional.course      no     yes   no
# 13      57    housemaid  divorced             basic.4y      no     yes   no
# 16      35  blue-collar   married             basic.6y      no     yes   no
# ...    ...          ...       ...                  ...     ...     ...  ...
# 41181   37       admin.   married    university.degree      no     yes   no
# 41183   73      retired   married  professional.course      no     yes   no
# 41184   46  blue-collar   married  professional.course      no      no   no
# 41186   44   technician   married  professional.course      no      no   no
# 41187   74      retired   married  professional.course      no     yes   no
#
# ...

# %%
for i in l:
    print(i)
# Out:
# housemaid
# services
# technician
# blue-collar
# retired
# self-employed
# unknown
# admin.
# management
# entrepreneur
# unemployed
# student

# %%
d = {0:{'housemaid':10000,'job':2000},1:{'housemaid':100000,'job':20000}}

# %%
d
# Out:
# {0: {'housemaid': 10000, 'job': 2000}, 1: {'housemaid': 100000, 'job': 20000}}

# %%
x = pd.DataFrame(d)

# %%
x
# Out:
#                0       1
# housemaid  10000  100000
# job         2000   20000

# %%
c_data
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'comm_type',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
e={}
d={}
for i in c_data:
    d={}
    for j in range(4):
        d[j]=dict(df[df['cluster']==j][i].value_counts())
    e[i]=d

# %%
x = pd.DataFrame(e['day_of_week'])
x
# Out:
#         0    1     2    3
# thu  2496  186  5082  859
# tue  2379  157  4829  725
# wed  2290  167  4835  842
# mon  2287  143  5356  728
# fri  2136  171  4810  710
