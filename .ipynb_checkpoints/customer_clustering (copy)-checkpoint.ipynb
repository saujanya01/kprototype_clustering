# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from kmodes.kprototypes import KPrototypes
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.datasets import make_blobs
from kneed import KneeLocator

# %%
df = pd.read_csv("https://raw.githubusercontent.com/saujanya01/kprototype_clustering/master/customer_data.csv")

# %%
customer = df[:100]
customer.head(5)
# Out:
#    age        job  marital    education  default housing loan  comm_type  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  last_contact_duration  campaign_contact_count  \
# 0   may         mon                    261                       1
# 1   may         mon                    149                       1
# 2   may         mon                    226                       1
# 3   may         mon                    151                       1
# 4   may         mon                    307                       1
#
#       poutcome  cons.price.idx  cons.conf.idx  nr.employed
# 0  nonexistent          93.994          -36.4       5191.0
# 1  nonexistent          93.994          -36.4       5191.0
# 2  nonexistent          93.994          -36.4       5191.0
# 3  nonexistent          93.994          -36.4       5191.0
# 4  nonexistent          93.994          -36.4       5191.0

# %% [markdown]
# ## Related to customer
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","blue-collar","entrepreneur","housemaid","management","retired","self-employed","services","student","technician","unemployed","unknown")
#
# 3 - marital : marital status (categorical: "divorced","married","single","unknown"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "basic.4y","basic.6y","basic.9y","high.school","illiterate","professional.course","university.degree","unknown")
#
# 5 - default: has credit in default? (categorical: "no","yes","unknown")
#
# 6 - housing: has housing loan? (categorical: "no","yes","unknown")
#
# 7 - loan: has personal loan? (categorical: "no","yes","unknown")
#
# ## related with the last contact of the current campaign:
#
# 8 - comm_type: contact communication type (categorical: "cellular","telephone")
#
# 9 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#
# 10 - day_of_week: last contact day of the week (categorical: "mon","tue","wed","thu","fri")
#
# 11 - last_contact_duration: last contact duration, in seconds (numeric). Important note:  this attribute highly affects the output target (e.g., if duration=0 then y="no"). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# ## other attributes(contact behaviour):
#
# 12 - campaign_contact_count: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 13 - poutcome: outcome of the previous marketing campaign (categorical: "failure","nonexistent","success")
#
# ## social and economic context attributes
#
# 14 - cons.price.idx: consumer price index - monthly indicator (numeric)
#
# 15 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
#
# 16 - nr.employed: number of employees - quarterly indicator (numeric)

# %%
customer.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'comm_type', 'month', 'day_of_week', 'last_contact_duration',
#        'campaign_contact_count', 'poutcome', 'cons.price.idx', 'cons.conf.idx',
#        'nr.employed'],
#       dtype='object')

# %% [markdown]
# ## Details of each column

# %%
for i in customer.columns:
    print(i)
    print(customer[i].value_counts())
    print("\n--------------------------------------\n")
# Out:
# age
# 55    9
# 41    7
# 42    6
# 57    6
# 54    5
# 37    5
# 44    5
# 35    5
# 56    4
# 39    4
# 45    4
# 33    3
# 50    3
# 49    3
# 38    3
# 59    3
# 25    3
# 34    2
# 40    2
# 60    2
# 46    2
# 47    2
# 51    2
# 53    2
# 48    1
# 52    1
# 32    1
# 31    1
# 30    1
# 29    1
# 58    1
# 24    1
# Name: age, dtype: int64
#
# --------------------------------------
#
# job
# admin.           26
# blue-collar      24
# technician       15
# services         10
# management        9
# unknown           4
# housemaid         3
# entrepreneur      3
# unemployed        3
# retired           2
# self-employed     1
# Name: job, dtype: int64
#
# --------------------------------------
#
# marital
# married     77
# single      16
# divorced     6
# unknown      1
# Name: marital, dtype: int64
#
# --------------------------------------
#
# education
# university.degree      23
# high.school            20
# basic.9y               14
# basic.4y               13
# unknown                11
# basic.6y               10
# professional.course     9
# Name: education, dtype: int64
#
# --------------------------------------
#
# default
# no         62
# unknown    38
# Name: default, dtype: int64
#
# --------------------------------------
#
# housing
# yes        50
# no         48
# unknown     2
# Name: housing, dtype: int64
#
# --------------------------------------
#
# loan
# no         81
# yes        17
# unknown     2
# Name: loan, dtype: int64
#
# --------------------------------------
#
# comm_type
# telephone    100
# Name: comm_type, dtype: int64
#
# --------------------------------------
#
# month
# may    100
# Name: month, dtype: int64
#
# --------------------------------------
#
# day_of_week
# mon    100
# Name: day_of_week, dtype: int64
#
# --------------------------------------
#
# last_contact_duration
# 188    2
# 174    2
# 212    2
# 208    2
# 366    2
#       ..
# 193    1
# 211    1
# 213    1
# 342    1
# 214    1
# Name: last_contact_duration, Length: 92, dtype: int64
#
# --------------------------------------
#
# campaign_contact_count
# 1    90
# 2    10
# Name: campaign_contact_count, dtype: int64
#
# --------------------------------------
#
# poutcome
# nonexistent    100
# Name: poutcome, dtype: int64
#
# --------------------------------------
#
# cons.price.idx
# 93.994    100
# Name: cons.price.idx, dtype: int64
#
# --------------------------------------
#
# cons.conf.idx
# -36.4    100
# Name: cons.conf.idx, dtype: int64
#
# --------------------------------------
#
# nr.employed
# 5191.0    100
# Name: nr.employed, dtype: int64
#
# --------------------------------------

# %% [markdown]
# ## Columns(numeric value) with cateorical values are stored in list 'ind'. 'c_data' has names of column with categorical data

# %%
ind = []
l = customer.dtypes
for i in range(len(l)):
    if (str(l[i])=='object'):
        ind.append(i)
c_data = [customer.columns[i] for i in ind]
c_data
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'comm_type',
#  'month',
#  'day_of_week',
#  'poutcome']

# %% [markdown]
# ## dictionary 'd' stores column name as key and index as value. In K-prototype all columns should have numeric indices

# %%
d={}
k=0
for i in customer.columns:
    d[i]=k
    k=k+1

# %% [markdown]
# ## Renaming the columns

# %%
customer.rename(columns=d,inplace=True)
# Out:
# /home/saujanya/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
customer.head(5)
# Out:
#    0          1        2            3        4    5    6          7    8   \
# 0  56  housemaid  married     basic.4y       no   no   no  telephone  may
# 1  57   services  married  high.school  unknown   no   no  telephone  may
# 2  37   services  married  high.school       no  yes   no  telephone  may
# 3  40     admin.  married     basic.6y       no   no   no  telephone  may
# 4  56   services  married  high.school       no   no  yes  telephone  may
#
#     9    10  11           12      13    14      15
# 0  mon  261   1  nonexistent  93.994 -36.4  5191.0
# 1  mon  149   1  nonexistent  93.994 -36.4  5191.0
# 2  mon  226   1  nonexistent  93.994 -36.4  5191.0
# 3  mon  151   1  nonexistent  93.994 -36.4  5191.0
# 4  mon  307   1  nonexistent  93.994 -36.4  5191.0

# %%
c_list=[]
cluster_dict={}
for i in range(1,11):
    kproto = KPrototypes(n_clusters=i, init='Cao', verbose=2)
    clusters = kproto.fit_predict(customer, categorical=ind)
    cluster_dict[i]=clusters
    c_list.append(kproto.cost_)
    print("------------------------------------------------------")
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 0, ncost: 7918580.066852473
# Best run was number 1
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 22, ncost: 4297017.123506178
# Run: 1, iteration: 2/100, moves: 18, ncost: 2861204.0906543555
# Run: 1, iteration: 3/100, moves: 4, ncost: 2445892.2205258436
# Run: 1, iteration: 4/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 3, ncost: 2601491.827097805
# Run: 3, iteration: 2/100, moves: 2, ncost: 2445892.2205258436
# Run: 3, iteration: 3/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 48, ncost: 5068482.850580754
# Run: 4, iteration: 2/100, moves: 27, ncost: 3447215.080550098
# Run: 4, iteration: 3/100, moves: 9, ncost: 2601491.827097805
# Run: 4, iteration: 4/100, moves: 2, ncost: 2445892.2205258436
# Run: 4, iteration: 5/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 7, ncost: 2601491.827097805
# Run: 5, iteration: 2/100, moves: 2, ncost: 2445892.2205258436
# Run: 5, iteration: 3/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 46, ncost: 5068482.850580754
# Run: 6, iteration: 2/100, moves: 27, ncost: 3447215.080550098
# Run: 6, iteration: 3/100, moves: 9, ncost: 2601491.827097805
# Run: 6, iteration: 4/100, moves: 2, ncost: 2445892.2205258436
# Run: 6, iteration: 5/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 25, ncost: 4422377.220865997
# Run: 7, iteration: 2/100, moves: 20, ncost: 2861204.0906543555
# Run: 7, iteration: 3/100, moves: 4, ncost: 2445892.2205258436
# Run: 7, iteration: 4/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 15, ncost: 2861204.0906543555
# Run: 8, iteration: 2/100, moves: 4, ncost: 2445892.2205258436
# Run: 8, iteration: 3/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 0, ncost: 2445892.2205258436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 15, ncost: 2861204.0906543555
# Run: 10, iteration: 2/100, moves: 4, ncost: 2445892.2205258436
# Run: 10, iteration: 3/100, moves: 0, ncost: 2445892.2205258436
# Best run was number 1
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 8, ncost: 1535090.414771186
# Run: 1, iteration: 2/100, moves: 10, ncost: 1279114.4271491298
# Run: 1, iteration: 3/100, moves: 1, ncost: 1277217.0605676246
# Run: 1, iteration: 4/100, moves: 1, ncost: 1276370.4020328624
# Run: 1, iteration: 5/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 53, ncost: 4484393.150812393
# Run: 2, iteration: 2/100, moves: 28, ncost: 2664778.3379864637
# Run: 2, iteration: 3/100, moves: 35, ncost: 1662682.7197225697
# Run: 2, iteration: 4/100, moves: 17, ncost: 1546628.3391695707
# Run: 2, iteration: 5/100, moves: 11, ncost: 1279114.4271491298
# Run: 2, iteration: 6/100, moves: 1, ncost: 1277217.0605676246
# Run: 2, iteration: 7/100, moves: 1, ncost: 1276370.4020328624
# Run: 2, iteration: 8/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 5, ncost: 1535090.414771186
# Run: 3, iteration: 2/100, moves: 10, ncost: 1279114.4271491298
# Run: 3, iteration: 3/100, moves: 1, ncost: 1277217.0605676246
# Run: 3, iteration: 4/100, moves: 1, ncost: 1276370.4020328624
# Run: 3, iteration: 5/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 10, ncost: 1492472.2750179952
# Run: 4, iteration: 2/100, moves: 3, ncost: 1279114.4271491298
# Run: 4, iteration: 3/100, moves: 1, ncost: 1277217.0605676246
# Run: 4, iteration: 4/100, moves: 1, ncost: 1276370.4020328624
# Run: 4, iteration: 5/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 21, ncost: 1885659.3453842418
# Run: 5, iteration: 2/100, moves: 16, ncost: 1592364.0413455414
# Run: 5, iteration: 3/100, moves: 12, ncost: 1312184.8020439032
# Run: 5, iteration: 4/100, moves: 6, ncost: 1279114.4271491298
# Run: 5, iteration: 5/100, moves: 1, ncost: 1277217.0605676246
# Run: 5, iteration: 6/100, moves: 1, ncost: 1276370.4020328624
# Run: 5, iteration: 7/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 41, ncost: 4200763.425755759
# Run: 6, iteration: 2/100, moves: 23, ncost: 2424762.4570050286
# Run: 6, iteration: 3/100, moves: 33, ncost: 1654501.7614589988
# Run: 6, iteration: 4/100, moves: 20, ncost: 1319379.7483246005
# Run: 6, iteration: 5/100, moves: 7, ncost: 1279114.4271491298
# Run: 6, iteration: 6/100, moves: 1, ncost: 1277217.0605676246
# Run: 6, iteration: 7/100, moves: 1, ncost: 1276370.4020328624
# Run: 6, iteration: 8/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 6, ncost: 1535090.414771186
# Run: 7, iteration: 2/100, moves: 10, ncost: 1279114.4271491298
# Run: 7, iteration: 3/100, moves: 1, ncost: 1277217.0605676246
# Run: 7, iteration: 4/100, moves: 1, ncost: 1276370.4020328624
# Run: 7, iteration: 5/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 47, ncost: 4337061.960886746
# Run: 8, iteration: 2/100, moves: 26, ncost: 2437485.9629920884
# Run: 8, iteration: 3/100, moves: 34, ncost: 1654501.7614589988
# Run: 8, iteration: 4/100, moves: 20, ncost: 1319379.7483246005
# Run: 8, iteration: 5/100, moves: 7, ncost: 1279114.4271491298
# Run: 8, iteration: 6/100, moves: 1, ncost: 1277217.0605676246
# Run: 8, iteration: 7/100, moves: 1, ncost: 1276370.4020328624
# Run: 8, iteration: 8/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 6, ncost: 1487709.891165951
# Run: 9, iteration: 2/100, moves: 2, ncost: 1279114.4271491298
# Run: 9, iteration: 3/100, moves: 1, ncost: 1277217.0605676246
# Run: 9, iteration: 4/100, moves: 1, ncost: 1276370.4020328624
# Run: 9, iteration: 5/100, moves: 0, ncost: 1276370.4020328624
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 23, ncost: 1842789.1556319185
# Run: 10, iteration: 2/100, moves: 18, ncost: 1546628.3391695707
# Run: 10, iteration: 3/100, moves: 11, ncost: 1279114.4271491298
# Run: 10, iteration: 4/100, moves: 1, ncost: 1277217.0605676246
# Run: 10, iteration: 5/100, moves: 1, ncost: 1276370.4020328624
# Run: 10, iteration: 6/100, moves: 0, ncost: 1276370.4020328624
# Best run was number 1
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 24, ncost: 1288283.25546436
# Run: 1, iteration: 2/100, moves: 4, ncost: 1079833.0269516653
# Run: 1, iteration: 3/100, moves: 2, ncost: 1076444.8515791264
# Run: 1, iteration: 4/100, moves: 0, ncost: 1076444.8515791264
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 3, ncost: 810724.3759662147
# Run: 2, iteration: 2/100, moves: 0, ncost: 810724.3759662147
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 9, ncost: 915844.6119919345
# Run: 3, iteration: 2/100, moves: 6, ncost: 878202.3123320716
# Run: 3, iteration: 3/100, moves: 4, ncost: 859457.7079709771
# Run: 3, iteration: 4/100, moves: 0, ncost: 859457.7079709771
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 4, ncost: 857802.8897035039
# Run: 4, iteration: 2/100, moves: 1, ncost: 857467.9828614144
# Run: 4, iteration: 3/100, moves: 0, ncost: 857467.9828614144
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 30, ncost: 1457900.520837909
# Run: 5, iteration: 2/100, moves: 19, ncost: 1099038.605811172
# Run: 5, iteration: 3/100, moves: 6, ncost: 1080890.2685488807
# Run: 5, iteration: 4/100, moves: 1, ncost: 1080326.5148681237
# Run: 5, iteration: 5/100, moves: 1, ncost: 1079659.6092205397
# Run: 5, iteration: 6/100, moves: 3, ncost: 1077403.0452479576
# Run: 5, iteration: 7/100, moves: 0, ncost: 1077403.0452479576
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 16, ncost: 1433925.8533029694
# Run: 6, iteration: 2/100, moves: 12, ncost: 1093333.1921129744
# Run: 6, iteration: 3/100, moves: 5, ncost: 1079659.6092205392
# Run: 6, iteration: 4/100, moves: 3, ncost: 1076744.14130982
# Run: 6, iteration: 5/100, moves: 1, ncost: 1076444.8515791264
# Run: 6, iteration: 6/100, moves: 0, ncost: 1076444.8515791264
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 14, ncost: 1310012.9842430535
# Run: 7, iteration: 2/100, moves: 3, ncost: 1090999.3345341603
# Run: 7, iteration: 3/100, moves: 4, ncost: 1080890.2685488807
# Run: 7, iteration: 4/100, moves: 1, ncost: 1080326.5148681237
# Run: 7, iteration: 5/100, moves: 1, ncost: 1079659.6092205397
# Run: 7, iteration: 6/100, moves: 3, ncost: 1077403.0452479576
# Run: 7, iteration: 7/100, moves: 0, ncost: 1077403.0452479576
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 11, ncost: 1310012.9842430535
# Run: 8, iteration: 2/100, moves: 3, ncost: 1090999.3345341603
# Run: 8, iteration: 3/100, moves: 4, ncost: 1080890.2685488807
# Run: 8, iteration: 4/100, moves: 1, ncost: 1080326.5148681237
# Run: 8, iteration: 5/100, moves: 1, ncost: 1079659.6092205397
# Run: 8, iteration: 6/100, moves: 3, ncost: 1077403.0452479576
# Run: 8, iteration: 7/100, moves: 0, ncost: 1077403.0452479576
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 19, ncost: 866895.4667408523
# Run: 9, iteration: 2/100, moves: 4, ncost: 858849.3321372203
# Run: 9, iteration: 3/100, moves: 2, ncost: 857467.9828614144
# Run: 9, iteration: 4/100, moves: 0, ncost: 857467.9828614144
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 14, ncost: 1452727.8574436596
# Run: 10, iteration: 2/100, moves: 12, ncost: 1094688.1991408933
# Run: 10, iteration: 3/100, moves: 5, ncost: 1080890.2685488807
# Run: 10, iteration: 4/100, moves: 1, ncost: 1080326.5148681237
# Run: 10, iteration: 5/100, moves: 1, ncost: 1079659.6092205397
# Run: 10, iteration: 6/100, moves: 3, ncost: 1077403.0452479576
# Run: 10, iteration: 7/100, moves: 0, ncost: 1077403.0452479576
# Best run was number 2
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 23, ncost: 1048485.174400931
# Run: 1, iteration: 2/100, moves: 20, ncost: 727727.6102877974
# Run: 1, iteration: 3/100, moves: 7, ncost: 718906.5371778627
# Run: 1, iteration: 4/100, moves: 0, ncost: 718906.5371778627
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 33, ncost: 1067625.2567626315
# Run: 2, iteration: 2/100, moves: 18, ncost: 734066.8664255077
# Run: 2, iteration: 3/100, moves: 3, ncost: 718351.3450883346
# Run: 2, iteration: 4/100, moves: 2, ncost: 717820.1463759507
# Run: 2, iteration: 5/100, moves: 0, ncost: 717820.1463759507
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 13, ncost: 1071257.1698646701
# Run: 3, iteration: 2/100, moves: 7, ncost: 749601.7756069012
# Run: 3, iteration: 3/100, moves: 4, ncost: 715813.9596850785
# Run: 3, iteration: 4/100, moves: 1, ncost: 713262.6496793288
# Run: 3, iteration: 5/100, moves: 2, ncost: 708336.5615426835
# Run: 3, iteration: 6/100, moves: 2, ncost: 707105.141444138
# Run: 3, iteration: 7/100, moves: 0, ncost: 707105.141444138
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 17, ncost: 770688.4617830339
# Run: 4, iteration: 2/100, moves: 4, ncost: 734808.5716775497
# Run: 4, iteration: 3/100, moves: 3, ncost: 715813.9596850785
# Run: 4, iteration: 4/100, moves: 1, ncost: 713262.6496793288
# Run: 4, iteration: 5/100, moves: 2, ncost: 708336.5615426835
# Run: 4, iteration: 6/100, moves: 2, ncost: 707105.141444138
# Run: 4, iteration: 7/100, moves: 0, ncost: 707105.141444138
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 14, ncost: 723748.1916578279
# Run: 5, iteration: 2/100, moves: 4, ncost: 719470.9921298285
# Run: 5, iteration: 3/100, moves: 2, ncost: 718732.3073798828
# Run: 5, iteration: 4/100, moves: 0, ncost: 718732.3073798828
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 7, ncost: 618849.8314552938
# Run: 6, iteration: 2/100, moves: 2, ncost: 600094.5629374561
# Run: 6, iteration: 3/100, moves: 0, ncost: 600094.5629374561
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 17, ncost: 707488.6395120252
# Run: 7, iteration: 2/100, moves: 3, ncost: 706208.4661659572
# Run: 7, iteration: 3/100, moves: 0, ncost: 706208.4661659572
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 49, ncost: 1734254.7577001806
# Run: 8, iteration: 2/100, moves: 28, ncost: 1024837.9915656898
# Run: 8, iteration: 3/100, moves: 20, ncost: 942163.1253210948
# Run: 8, iteration: 4/100, moves: 15, ncost: 778636.9154512889
# Run: 8, iteration: 5/100, moves: 7, ncost: 734808.5716775497
# Run: 8, iteration: 6/100, moves: 3, ncost: 715813.9596850785
# Run: 8, iteration: 7/100, moves: 1, ncost: 713262.6496793288
# Run: 8, iteration: 8/100, moves: 2, ncost: 708336.5615426835
# Run: 8, iteration: 9/100, moves: 2, ncost: 707105.141444138
# Run: 8, iteration: 10/100, moves: 0, ncost: 707105.141444138
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 28, ncost: 1229224.3204913675
# Run: 9, iteration: 2/100, moves: 13, ncost: 967756.6043825392
# Run: 9, iteration: 3/100, moves: 17, ncost: 835605.3299353522
# Run: 9, iteration: 4/100, moves: 14, ncost: 734808.5716775497
# Run: 9, iteration: 5/100, moves: 3, ncost: 715813.9596850785
# Run: 9, iteration: 6/100, moves: 1, ncost: 713262.6496793288
# Run: 9, iteration: 7/100, moves: 2, ncost: 708336.5615426835
# Run: 9, iteration: 8/100, moves: 2, ncost: 707105.141444138
# Run: 9, iteration: 9/100, moves: 0, ncost: 707105.141444138
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 36, ncost: 743116.1923220952
# Run: 10, iteration: 2/100, moves: 10, ncost: 718875.4592746032
# Run: 10, iteration: 3/100, moves: 1, ncost: 718732.3073798827
# Run: 10, iteration: 4/100, moves: 0, ncost: 718732.3073798827
# Best run was number 6
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 32, ncost: 1420453.7992414476
# Run: 1, iteration: 2/100, moves: 22, ncost: 891789.3944442387
# Run: 1, iteration: 3/100, moves: 19, ncost: 680217.5135254032
# Run: 1, iteration: 4/100, moves: 11, ncost: 630389.0901313825
# Run: 1, iteration: 5/100, moves: 2, ncost: 629721.857469381
# Run: 1, iteration: 6/100, moves: 0, ncost: 629721.857469381
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 51, ncost: 1666314.3196007356
# Run: 2, iteration: 2/100, moves: 23, ncost: 981424.4035853172
# Run: 2, iteration: 3/100, moves: 16, ncost: 925969.378189448
# Run: 2, iteration: 4/100, moves: 19, ncost: 747007.0975253093
# Run: 2, iteration: 5/100, moves: 12, ncost: 689647.4877639456
# Run: 2, iteration: 6/100, moves: 17, ncost: 634767.3141995741
# Run: 2, iteration: 7/100, moves: 6, ncost: 631073.7718407406
# Run: 2, iteration: 8/100, moves: 1, ncost: 630726.5337199009
# Run: 2, iteration: 9/100, moves: 0, ncost: 630726.5337199009
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 39, ncost: 1435641.3138871118
# Run: 3, iteration: 2/100, moves: 16, ncost: 957448.134775834
# Run: 3, iteration: 3/100, moves: 17, ncost: 786642.2224425753
# Run: 3, iteration: 4/100, moves: 13, ncost: 692239.8110444862
# Run: 3, iteration: 5/100, moves: 17, ncost: 634240.000093037
# Run: 3, iteration: 6/100, moves: 5, ncost: 630375.8905255161
# Run: 3, iteration: 7/100, moves: 0, ncost: 630375.8905255161
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 19, ncost: 1192491.333169281
# Run: 4, iteration: 2/100, moves: 14, ncost: 907144.8639368713
# Run: 4, iteration: 3/100, moves: 19, ncost: 721125.5162856061
# Run: 4, iteration: 4/100, moves: 10, ncost: 660943.919403346
# Run: 4, iteration: 5/100, moves: 12, ncost: 630375.8905255161
# Run: 4, iteration: 6/100, moves: 0, ncost: 630375.8905255161
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 21, ncost: 987145.3284328633
# Run: 5, iteration: 2/100, moves: 11, ncost: 955073.7642473163
# Run: 5, iteration: 3/100, moves: 19, ncost: 796279.2954432975
# Run: 5, iteration: 4/100, moves: 12, ncost: 727459.4511619078
# Run: 5, iteration: 5/100, moves: 3, ncost: 708199.500051259
# Run: 5, iteration: 6/100, moves: 1, ncost: 705502.1545863856
# Run: 5, iteration: 7/100, moves: 2, ncost: 700747.0720979616
# Run: 5, iteration: 8/100, moves: 5, ncost: 688693.4465636209
# Run: 5, iteration: 9/100, moves: 5, ncost: 679520.2779442009
# Run: 5, iteration: 10/100, moves: 7, ncost: 667626.9752077145
# Run: 5, iteration: 11/100, moves: 15, ncost: 638516.4394203261
# Run: 5, iteration: 12/100, moves: 8, ncost: 630375.8905255161
# Run: 5, iteration: 13/100, moves: 0, ncost: 630375.8905255161
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 5, ncost: 457322.62385792134
# Run: 6, iteration: 2/100, moves: 0, ncost: 457322.62385792134
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 13, ncost: 568329.0155699626
# Run: 7, iteration: 2/100, moves: 2, ncost: 568305.139307336
# Run: 7, iteration: 3/100, moves: 0, ncost: 568305.139307336
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 10, ncost: 639349.1442777168
# Run: 8, iteration: 2/100, moves: 1, ncost: 638974.7899322034
# Run: 8, iteration: 3/100, moves: 7, ncost: 634144.266813874
# Run: 8, iteration: 4/100, moves: 3, ncost: 631254.4437195263
# Run: 8, iteration: 5/100, moves: 2, ncost: 630606.1436901824
# Run: 8, iteration: 6/100, moves: 0, ncost: 630606.1436901824
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 19, ncost: 694451.2161003684
# Run: 9, iteration: 2/100, moves: 2, ncost: 692359.4890296628
# Run: 9, iteration: 3/100, moves: 3, ncost: 691406.0968251234
# Run: 9, iteration: 4/100, moves: 0, ncost: 691406.0968251234
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 34, ncost: 933314.4348879886
# Run: 10, iteration: 2/100, moves: 29, ncost: 728850.2297978872
# Run: 10, iteration: 3/100, moves: 15, ncost: 640558.4896907895
# Run: 10, iteration: 4/100, moves: 5, ncost: 630375.8905255161
# Run: 10, iteration: 5/100, moves: 0, ncost: 630375.8905255161
# Best run was number 6
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 50, ncost: 2027613.7491776964
# Run: 1, iteration: 2/100, moves: 26, ncost: 1189296.2080495583
# Run: 1, iteration: 3/100, moves: 11, ncost: 922292.4859728483
# Run: 1, iteration: 4/100, moves: 17, ncost: 726558.20226437
# Run: 1, iteration: 5/100, moves: 10, ncost: 666579.0182919268
# Run: 1, iteration: 6/100, moves: 15, ncost: 618348.4325026638
# Run: 1, iteration: 7/100, moves: 2, ncost: 617189.893790666
# Run: 1, iteration: 8/100, moves: 4, ncost: 612614.4519767379
# Run: 1, iteration: 9/100, moves: 3, ncost: 612145.8802579625
# Run: 1, iteration: 10/100, moves: 0, ncost: 612145.8802579625
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 22, ncost: 638129.6625992336
# Run: 2, iteration: 2/100, moves: 5, ncost: 633243.3855688997
# Run: 2, iteration: 3/100, moves: 2, ncost: 632059.1768841146
# Run: 2, iteration: 4/100, moves: 8, ncost: 626746.1730645387
# Run: 2, iteration: 5/100, moves: 2, ncost: 626385.6869935791
# Run: 2, iteration: 6/100, moves: 0, ncost: 626385.6869935791
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 27, ncost: 606782.7597649853
# Run: 3, iteration: 2/100, moves: 4, ncost: 602070.9328192879
# Run: 3, iteration: 3/100, moves: 0, ncost: 602070.9328192879
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 25, ncost: 448189.92466831004
# Run: 4, iteration: 2/100, moves: 5, ncost: 395853.7680443632
# Run: 4, iteration: 3/100, moves: 10, ncost: 382879.506397872
# Run: 4, iteration: 4/100, moves: 2, ncost: 382519.0203269123
# Run: 4, iteration: 5/100, moves: 0, ncost: 382519.0203269123
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 35, ncost: 653945.4043101429
# Run: 5, iteration: 2/100, moves: 14, ncost: 610812.8910585046
# Run: 5, iteration: 3/100, moves: 5, ncost: 607842.5678769787
# Run: 5, iteration: 4/100, moves: 1, ncost: 607734.5842327648
# Run: 5, iteration: 5/100, moves: 0, ncost: 607734.5842327648
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 21, ncost: 391143.51361668267
# Run: 6, iteration: 2/100, moves: 4, ncost: 383749.01086555846
# Run: 6, iteration: 3/100, moves: 0, ncost: 383749.01086555846
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 9, ncost: 425633.87970719114
# Run: 7, iteration: 2/100, moves: 0, ncost: 425633.87970719114
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 25, ncost: 577341.3344522159
# Run: 8, iteration: 2/100, moves: 5, ncost: 447491.33187310636
# Run: 8, iteration: 3/100, moves: 11, ncost: 389375.96813073696
# Run: 8, iteration: 4/100, moves: 4, ncost: 385104.4068050885
# Run: 8, iteration: 5/100, moves: 0, ncost: 385104.4068050885
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 34, ncost: 440253.7674890589
# Run: 9, iteration: 2/100, moves: 10, ncost: 416837.58320507867
# Run: 9, iteration: 3/100, moves: 17, ncost: 391129.08387007803
# Run: 9, iteration: 4/100, moves: 2, ncost: 390934.0680423981
# Run: 9, iteration: 5/100, moves: 0, ncost: 390934.0680423981
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 14, ncost: 933793.6538246181
# Run: 10, iteration: 2/100, moves: 13, ncost: 638756.0987371262
# Run: 10, iteration: 3/100, moves: 14, ncost: 577695.3388977058
# Run: 10, iteration: 4/100, moves: 14, ncost: 438521.51425632637
# Run: 10, iteration: 5/100, moves: 3, ncost: 387745.4211199451
# Run: 10, iteration: 6/100, moves: 1, ncost: 383961.7715109709
# Run: 10, iteration: 7/100, moves: 0, ncost: 383961.7715109709
# Best run was number 4
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 17, ncost: 559937.9553070086
# Run: 1, iteration: 2/100, moves: 16, ncost: 377938.0039548737
# Run: 1, iteration: 3/100, moves: 16, ncost: 353936.4899070851
# Run: 1, iteration: 4/100, moves: 0, ncost: 353936.4899070851
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 20, ncost: 839947.2214093213
# Run: 2, iteration: 2/100, moves: 13, ncost: 592374.3455653163
# Run: 2, iteration: 3/100, moves: 2, ncost: 592069.7275374507
# Run: 2, iteration: 4/100, moves: 0, ncost: 592069.7275374507
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 51, ncost: 557303.1103761516
# Run: 3, iteration: 2/100, moves: 16, ncost: 379370.66994905664
# Run: 3, iteration: 3/100, moves: 10, ncost: 358626.7256822006
# Run: 3, iteration: 4/100, moves: 3, ncost: 356719.29823092505
# Run: 3, iteration: 5/100, moves: 0, ncost: 356719.29823092505
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 17, ncost: 429191.0213298453
# Run: 4, iteration: 2/100, moves: 2, ncost: 382511.9814998664
# Run: 4, iteration: 3/100, moves: 0, ncost: 382511.9814998664
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 27, ncost: 599174.8347198619
# Run: 5, iteration: 2/100, moves: 8, ncost: 591131.3041999338
# Run: 5, iteration: 3/100, moves: 2, ncost: 590840.2406718427
# Run: 5, iteration: 4/100, moves: 0, ncost: 590840.2406718427
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 18, ncost: 597486.0652697657
# Run: 6, iteration: 2/100, moves: 10, ncost: 586611.4714099971
# Run: 6, iteration: 3/100, moves: 1, ncost: 586506.6219493466
# Run: 6, iteration: 4/100, moves: 2, ncost: 583625.4926743689
# Run: 6, iteration: 5/100, moves: 2, ncost: 581829.7887119718
# Run: 6, iteration: 6/100, moves: 1, ncost: 581695.1489066612
# Run: 6, iteration: 7/100, moves: 0, ncost: 581695.1489066612
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 27, ncost: 977768.0783189817
# Run: 7, iteration: 2/100, moves: 11, ncost: 616611.5014248777
# Run: 7, iteration: 3/100, moves: 2, ncost: 600520.3300000699
# Run: 7, iteration: 4/100, moves: 1, ncost: 599250.5246766268
# Run: 7, iteration: 5/100, moves: 0, ncost: 599250.5246766268
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 19, ncost: 615858.2121948134
# Run: 8, iteration: 2/100, moves: 10, ncost: 587590.9980235934
# Run: 8, iteration: 3/100, moves: 2, ncost: 587169.6361819573
# Run: 8, iteration: 4/100, moves: 1, ncost: 586947.2034651205
# Run: 8, iteration: 5/100, moves: 0, ncost: 586947.2034651205
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 16, ncost: 357417.2284285839
# Run: 9, iteration: 2/100, moves: 0, ncost: 357417.2284285839
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 20, ncost: 612968.92976355
# Run: 10, iteration: 2/100, moves: 9, ncost: 591082.8700859651
# Run: 10, iteration: 3/100, moves: 9, ncost: 586723.7843633624
# Run: 10, iteration: 4/100, moves: 0, ncost: 586723.7843633624
# Best run was number 1
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 19, ncost: 533236.3912755518
# Run: 1, iteration: 2/100, moves: 10, ncost: 359963.13811796793
# Run: 1, iteration: 3/100, moves: 3, ncost: 351614.91118290933
# Run: 1, iteration: 4/100, moves: 0, ncost: 351614.91118290933
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 29, ncost: 418409.6220923265
# Run: 2, iteration: 2/100, moves: 8, ncost: 366163.051020588
# Run: 2, iteration: 3/100, moves: 2, ncost: 365617.92344937625
# Run: 2, iteration: 4/100, moves: 0, ncost: 365617.92344937625
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 17, ncost: 597197.6506974027
# Run: 3, iteration: 2/100, moves: 5, ncost: 569524.5793358396
# Run: 3, iteration: 3/100, moves: 2, ncost: 568365.8856510636
# Run: 3, iteration: 4/100, moves: 0, ncost: 568365.8856510636
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 15, ncost: 386765.252363836
# Run: 4, iteration: 2/100, moves: 11, ncost: 366994.57771181327
# Run: 4, iteration: 3/100, moves: 4, ncost: 363011.991789265
# Run: 4, iteration: 4/100, moves: 0, ncost: 363011.991789265
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 27, ncost: 533548.2610157302
# Run: 5, iteration: 2/100, moves: 9, ncost: 396867.8211636428
# Run: 5, iteration: 3/100, moves: 3, ncost: 340737.72220797074
# Run: 5, iteration: 4/100, moves: 1, ncost: 337111.2518325457
# Run: 5, iteration: 5/100, moves: 0, ncost: 337111.2518325457
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 31, ncost: 537984.9740539341
# Run: 6, iteration: 2/100, moves: 7, ncost: 407173.8700207152
# Run: 6, iteration: 3/100, moves: 3, ncost: 355536.306191972
# Run: 6, iteration: 4/100, moves: 2, ncost: 347875.04836505675
# Run: 6, iteration: 5/100, moves: 0, ncost: 347875.04836505675
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 17, ncost: 841166.2308312275
# Run: 7, iteration: 2/100, moves: 8, ncost: 583040.8788534825
# Run: 7, iteration: 3/100, moves: 2, ncost: 582676.3587970446
# Run: 7, iteration: 4/100, moves: 2, ncost: 582513.6486732264
# Run: 7, iteration: 5/100, moves: 0, ncost: 582513.6486732264
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 24, ncost: 365988.661567291
# Run: 8, iteration: 2/100, moves: 4, ncost: 347435.274539144
# Run: 8, iteration: 3/100, moves: 2, ncost: 345826.8023622576
# Run: 8, iteration: 4/100, moves: 0, ncost: 345826.8023622576
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 24, ncost: 389863.86237147584
# Run: 9, iteration: 2/100, moves: 4, ncost: 337419.3482489396
# Run: 9, iteration: 3/100, moves: 0, ncost: 337419.3482489396
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 31, ncost: 908824.3201530391
# Run: 10, iteration: 2/100, moves: 10, ncost: 605383.7290565745
# Run: 10, iteration: 3/100, moves: 7, ncost: 588251.8641910029
# Run: 10, iteration: 4/100, moves: 1, ncost: 588034.1528877483
# Run: 10, iteration: 5/100, moves: 1, ncost: 587933.6598163196
# Run: 10, iteration: 6/100, moves: 0, ncost: 587933.6598163196
# Best run was number 5
# ------------------------------------------------------
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 21, ncost: 352469.2476320756
# Run: 1, iteration: 2/100, moves: 14, ncost: 330061.52343910624
# Run: 1, iteration: 3/100, moves: 7, ncost: 327533.3434004448
# Run: 1, iteration: 4/100, moves: 0, ncost: 327533.3434004448
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 17, ncost: 408611.5529206796
# Run: 2, iteration: 2/100, moves: 5, ncost: 355581.70945127634
# Run: 2, iteration: 3/100, moves: 2, ncost: 346613.5388711383
# Run: 2, iteration: 4/100, moves: 2, ncost: 345766.1789297344
# Run: 2, iteration: 5/100, moves: 0, ncost: 345766.1789297344
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 23, ncost: 833891.041115859
# Run: 3, iteration: 2/100, moves: 9, ncost: 568003.130155729
# Run: 3, iteration: 3/100, moves: 1, ncost: 567956.4105790093
# Run: 3, iteration: 4/100, moves: 0, ncost: 567956.4105790093
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 13, ncost: 370962.4093491995
# Run: 4, iteration: 2/100, moves: 12, ncost: 319805.127303327
# Run: 4, iteration: 3/100, moves: 2, ncost: 318683.93863730744
# Run: 4, iteration: 4/100, moves: 0, ncost: 318683.93863730744
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 30, ncost: 504774.461845197
# Run: 5, iteration: 2/100, moves: 15, ncost: 332111.7756254864
# Run: 5, iteration: 3/100, moves: 5, ncost: 325952.5458079376
# Run: 5, iteration: 4/100, moves: 0, ncost: 325952.5458079376
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/100, moves: 34, ncost: 578666.8707419585
# Run: 6, iteration: 2/100, moves: 6, ncost: 568769.3976366323
# Run: 6, iteration: 3/100, moves: 1, ncost: 568644.465777222
# Run: 6, iteration: 4/100, moves: 0, ncost: 568644.465777222
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/100, moves: 19, ncost: 346535.3080738664
# Run: 7, iteration: 2/100, moves: 4, ncost: 344115.7619063624
# Run: 7, iteration: 3/100, moves: 3, ncost: 342574.32702742406
# Run: 7, iteration: 4/100, moves: 0, ncost: 342574.32702742406
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/100, moves: 21, ncost: 348107.56184608076
# Run: 8, iteration: 2/100, moves: 4, ncost: 331972.50807208533
# Run: 8, iteration: 3/100, moves: 0, ncost: 331972.50807208533
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/100, moves: 22, ncost: 342102.45050709764
# Run: 9, iteration: 2/100, moves: 6, ncost: 332293.7562599153
# Run: 9, iteration: 3/100, moves: 2, ncost: 330300.4345259144
# Run: 9, iteration: 4/100, moves: 0, ncost: 330300.4345259144
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/100, moves: 25, ncost: 572322.1397677674
# Run: 10, iteration: 2/100, moves: 7, ncost: 564625.9917963805
# Run: 10, iteration: 3/100, moves: 1, ncost: 564557.3989262665
# Run: 10, iteration: 4/100, moves: 0, ncost: 564557.3989262665
# Best run was number 4
# ------------------------------------------------------

# %% [markdown]
# ## Elbow Plot

# %%
sns.lineplot(y=c_list,x=range(0,len(c_list)))

# %% [markdown]
# ## Locating Elbow for adequate number of cluster

# %%
y=c_list
x = range(1, len(y)+1)
kn = KneeLocator(x, y, curve='convex', direction='decreasing')
print("Number of clusters : ",kn.knee)
# Out:
# Number of clusters :  3

# %% [markdown]
# ## Every cluster is stored in dictionary cd(starting from index 0). cd[n]=(n-1)th cluster

# %%
final_cluster = cluster_dict[kn.knee]
cd={}
for i in range(kn.knee):
    cd[i]=[]
    
for i in range(0,len(final_cluster)):
    cd[final_cluster[i]].append(list(customer.iloc[i]))

column = list(df.columns)
for i in range(len(cd)):
    cd[i]=pd.DataFrame(cd[i],columns=column)

# %%
cd[0]
# Out:
#     age          job   marital            education  default housing loan  \
# 0    56    housemaid   married             basic.4y       no      no   no
# 1    57     services   married          high.school  unknown      no   no
# 2    37     services   married          high.school       no     yes   no
# 3    40       admin.   married             basic.6y       no      no   no
# 4    56     services   married          high.school       no      no  yes
# ..  ...          ...       ...                  ...      ...     ...  ...
# 65   60       admin.   married              unknown  unknown      no  yes
# 66   45     services   married  professional.course       no     yes   no
# 67   53       admin.  divorced    university.degree  unknown      no   no
# 68   37   technician    single  professional.course       no      no   no
# 69   44  blue-collar   married             basic.6y       no      no   no
#
#     comm_type month day_of_week  last_contact_duration  \
# 0   telephone   may         mon                    261
# 1   telephone   may         mon                    149
# 2   telephone   may         mon                    226
# 3   telephone   may         mon                    151
# 4   telephone   may         mon                    307
# ..        ...   ...         ...                    ...
# 65  telephone   may         mon                    213
# 66  telephone   may         mon                    221
# 67  telephone   may         mon                    287
# 68  telephone   may         mon                    197
# 69  telephone   may         mon                    257
#
#     campaign_contact_count     poutcome  cons.price.idx  cons.conf.idx  \
# 0                        1  nonexistent          93.994          -36.4
# 1                        1  nonexistent          93.994          -36.4
# 2                        1  nonexistent          93.994          -36.4
# 3                        1  nonexistent          93.994          -36.4
# 4                        1  nonexistent          93.994          -36.4
# ..                     ...          ...             ...            ...
# 65                       2  nonexistent          93.994          -36.4
# 66                       1  nonexistent          93.994          -36.4
# 67                       1  nonexistent          93.994          -36.4
# 68                       1  nonexistent          93.994          -36.4
# 69                       1  nonexistent          93.994          -36.4
#
#     nr.employed
# 0        5191.0
# 1        5191.0
# 2        5191.0
# 3        5191.0
# 4        5191.0
# ..          ...
# 65       5191.0
# 66       5191.0
# 67       5191.0
# 68       5191.0
# 69       5191.0
#
# [70 rows x 16 columns]

# %%
cd[1].head(5)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   24   technician   single  professional.course       no     yes   no
# 1   35  blue-collar  married             basic.6y       no     yes   no
# 2   46  blue-collar  married             basic.6y  unknown     yes  yes
# 3   50  blue-collar  married             basic.9y       no     yes  yes
# 4   55      retired   single          high.school       no     yes   no
#
#    comm_type month day_of_week  last_contact_duration  campaign_contact_count  \
# 0  telephone   may         mon                    380                       1
# 1  telephone   may         mon                    312                       1
# 2  telephone   may         mon                    440                       1
# 3  telephone   may         mon                    353                       1
# 4  telephone   may         mon                    342                       1
#
#       poutcome  cons.price.idx  cons.conf.idx  nr.employed
# 0  nonexistent          93.994          -36.4       5191.0
# 1  nonexistent          93.994          -36.4       5191.0
# 2  nonexistent          93.994          -36.4       5191.0
# 3  nonexistent          93.994          -36.4       5191.0
# 4  nonexistent          93.994          -36.4       5191.0

# %%
cd[2].head(5)
# Out:
#    age           job   marital          education  default housing loan  \
# 0   52    technician   married           basic.9y       no     yes   no
# 1   41   blue-collar  divorced           basic.4y  unknown     yes   no
# 2   49  entrepreneur   married  university.degree  unknown     yes   no
# 3   49    technician   married           basic.9y       no      no   no
#
#    comm_type month day_of_week  last_contact_duration  campaign_contact_count  \
# 0  telephone   may         mon                   1666                       1
# 1  telephone   may         mon                   1575                       1
# 2  telephone   may         mon                   1042                       1
# 3  telephone   may         mon                   1467                       1
#
#       poutcome  cons.price.idx  cons.conf.idx  nr.employed
# 0  nonexistent          93.994          -36.4       5191.0
# 1  nonexistent          93.994          -36.4       5191.0
# 2  nonexistent          93.994          -36.4       5191.0
# 3  nonexistent          93.994          -36.4       5191.0

# %%
sns.catplot(x='marital',data=cd[0])
